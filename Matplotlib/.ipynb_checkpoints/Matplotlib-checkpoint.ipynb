# %%
import pandas as pd
import numpy as np

# %%
# %pip install matplotlib

# %% [markdown]
# #### **Matplotlib Basics**

# %% [markdown]
# #### **Subplots in Matplotlib**

# %% [markdown]
# #### **Object Oriented Way**

# %% [markdown]
# #### **Type of Plots**

# %% [markdown]
# #### **Saving Plots**

# %% [markdown]
# #### **Working with Images**

# %% [markdown]
# #### **Optional Designing**
